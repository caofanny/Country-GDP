# %% [markdown]
# # Phase II: Data Curation, Exploratory Analysis and Plotting (5\%)
#
# ### Team Members:
# - Gokul Ramanan
# - Fanny
# - Gensen
# - Haojin
#
#
# ## Part 1:
# (1%) Expresses the central motivation of the project and explains the (at least) two key questions to be explored. Gives a summary of the data processing pipeline so a technical expert can easily follow along.

# %% [markdown]
# ## Problem Motivation

# %% [markdown]
# ## Summary of the Data Processing Pipeline

# %% [markdown]
# ## Part 2:
# (2\%) Obtains, cleans, and merges all data sources involved in the project.

# %%
# !pip install wbdata
# Out:
# Collecting wbdata
#   Downloading wbdata-1.1.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: appdirs<2,>=1.4 in c:\users\evanb\anaconda3\lib\site-packages (from wbdata) (1.4.4)
# Collecting backoff<3,>=2.2.1 (from wbdata)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: cachetools<6,>=5.3.2 in c:\users\evanb\anaconda3\lib\site-packages (from wbdata) (5.5.1)
# Collecting dateparser<2,>=1.2.0 (from wbdata)
#   Downloading dateparser-1.2.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: decorator<6,>=5.1.1 in c:\users\evanb\anaconda3\lib\site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3,>=2.0 in c:\users\evanb\anaconda3\lib\site-packages (from wbdata) (2.32.3)
# Collecting shelved-cache<0.4,>=0.3.1 (from wbdata)
#   Downloading shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: tabulate<1,>=0.8.5 in c:\users\evanb\anaconda3\lib\site-packages (from wbdata) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\evanb\anaconda3\lib\site-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Collecting pytz>=2024.2 (from dateparser<2,>=1.2.0->wbdata)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\evanb\anaconda3\lib\site-packages (from dateparser<2,>=1.2.0->wbdata) (2024.11.6)
# Collecting tzlocal>=0.2 (from dateparser<2,>=1.2.0->wbdata)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\evanb\anaconda3\lib\site-packages (from requests<3,>=2.0->wbdata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\evanb\anaconda3\lib\site-packages (from requests<3,>=2.0->wbdata) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\evanb\anaconda3\lib\site-packages (from requests<3,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\evanb\anaconda3\lib\site-packages (from requests<3,>=2.0->wbdata) (2025.8.3)
# Requirement already satisfied: six>=1.5 in c:\users\evanb\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)
# Requirement already satisfied: tzdata in c:\users\evanb\anaconda3\lib\site-packages (from tzlocal>=0.2->dateparser<2,>=1.2.0->wbdata) (2025.2)
# Downloading wbdata-1.1.0-py3-none-any.whl (18 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading dateparser-1.2.2-py3-none-any.whl (315 kB)
# Downloading shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: pytz, tzlocal, shelved-cache, backoff, dateparser, wbdata
#
#   Attempting uninstall: pytz
#
#     Found existing installation: pytz 2024.1
#
#     Uninstalling pytz-2024.1:
#
#       Successfully uninstalled pytz-2024.1
#
#    ---------------------------------------- 0/6 [pytz]
#    ---------------------------------------- 0/6 [pytz]
#    ------ --------------------------------- 1/6 [tzlocal]
#    -------------------------- ------------- 4/6 [dateparser]
#    -------------------------- ------------- 4/6 [dateparser]
#    -------------------------- ------------- 4/6 [dateparser]
#    ---------------------------------------- 6/6 [wbdata]
#
# Successfully installed backoff-2.2.1 dateparser-1.2.2 pytz-2025.2 shelved-cache-0.3.1 tzlocal-5.3.1 wbdata-1.1.0

# %%
import wbdata as wb
import pandas as pd
import datetime as dt

# %%
def clean_data(countries, indicators, year_start, year_end):
  """
    Fetch and preprocess World Bank indicator data for specified countries and years.

    This function retrieves data from the World Bank API for the given indicators and countries,
    converts the date column to integer years, and filters the results to include only data within
    the specified year range.

    Parameters
    ----------
    countries : list of str
        A list of country codes (e.g., ["IN", "US", "CN"]) to retrieve data for.
    indicators : dict
        A dictionary mapping indicator names to World Bank indicator codes.
        Example: {"GDP per capita": "NY.GDP.PCAP.CD"}
    year_start : int
        The starting year of the desired time range.
    year_end : int
        The ending year of the desired time range.

    Returns
    -------
    pandas.DataFrame
        A cleaned DataFrame containing country, date (year), and indicator values
        filtered to the specified range, with a flat index for easier use.
  """

  data = wb.get_dataframe(indicators, country=countries).reset_index()
  data["date"] = data["date"].astype(int)
  data = data[(data["date"] <= year_end) & (data["date"] >= year_start)]

  return data


# List of the top 20 countries ranked by GDP in 2024
# (using ISO-3 country codes as defined by the World Bank API)

countries = ["US", "CN", "DE", "JP", "IN", "GB", "FR", "IT", "CA", "BR", "RU", "MX",
             "AU", "ES", "KR", "ID", "TR", "SA", "NL", "CH"]

# Dictionary of World Bank indicators for GDP growth prediction
# Key = World Bank indicator code
# Value = Custom short name
# Units commented next to each indicator

indicators = {
    # Demographics & Population
    "EN.POP.DNST": "population_density",       # people per sq. km of land area
    "SP.POP.TOTL": "total_population",         # number of people
    "SP.URB.TOTL.IN.ZS": "urban_population_pct", # % of total population living in urban areas
    "SP.DYN.TFRT.IN": "fertility_rate",        # births per woman
    "SP.POP.DPND": "age_dependency_ratio",     # % of working-age population (dependents per 100 working-age people)

    # Health & Capital
    "SP.DYN.LE00.IN": "life_expectancy",       # years
    "SP.DYN.IMRT.IN": "infant_mortality",      # per 1,000 live births
    "SH.XPD.CHEX.PC.CD": "health_exp_pc",      # US$ per capita (current)
    "SH.XPD.CHEX.GD.ZS": "health_exp_gdp_pct", # % of GDP

    # Education System
    "SE.ADT.LITR.ZS": "adult_literacy",        # % of people ages 15+
    "SE.PRM.ENRR": "primary_school_enroll",    # % gross enrollment ratio
    "SE.SEC.ENRR": "secondary_school_enroll",  # % gross enrollment ratio
    "SE.TER.ENRR": "tertiary_school_enroll",   # % gross enrollment ratio
    "SE.XPD.TOTL.GD.ZS": "edu_exp_gdp_pct",    # % of GDP spent on education

    # Economy & Market Growth
    "NY.GDP.PCAP.CD": "gdp_per_capita",        # current US$
    "NE.GDI.TOTL.ZS": "gross_capital_form_pct",# % of GDP (investment)
    "FP.CPI.TOTL.ZG": "inflation_rate",        # annual %, consumer prices
    "SL.UEM.TOTL.ZS": "unemployment_rate",     # % of total labor force
    "NE.TRD.GNFS.ZS": "trade_pct_gdp",         # % of GDP (exports + imports)
    "BX.KLT.DINV.WD.GD.ZS": "fdi_inflows_pct"  # % of GDP (net inflows of FDI)
}

# We want the dataset to include only years between 1980 and 2022
cleaned_data = clean_data(countries, indicators, 1980, 2022)

print(f"The data has {cleaned_data.shape[1]} features and {cleaned_data.shape[0]} observations.")

# Save the cleaned data into a csv for reuseability for ML practice
cleaned_data.to_csv("top20_gdp_indicators_1980_2022.csv", index=False)
# Out:
# The data has 22 features and 860 observations.

# %%
# Test
# Printing first 50 rows of the first cleaned CSV file
gdp_clean_data = pd.read_csv("top20_gdp_indicators_1980_2022.csv")
gdp_clean_data.head(20)
# Out:
#       country  date  population_density  total_population  \
# 0   Australia  2022            3.381998        26014399.0
# 1   Australia  2021            3.339228        25685412.0
# 2   Australia  2020            3.334527        25649248.0
# 3   Australia  2019            3.293651        25334826.0
# 4   Australia  2018            3.245345        24963258.0
# 5   Australia  2017            3.197156        24592588.0
# 6   Australia  2016            3.144936        24190907.0
# 7   Australia  2015            3.100113        23815995.0
# 8   Australia  2014            3.055815        23475686.0
# 9   Australia  2013            3.010574        23128129.0
# 10  Australia  2012            2.959200        22733465.0
# 11  Australia  2011            2.907986        22340024.0
# 12  Australia  2010            2.867859        22031750.0
# 13  Australia  2009            2.823588        21691653.0
# 14  Australia  2008            2.765994        21249199.0
# 15  Australia  2007            2.711118        20827622.0
# 16  Australia  2006            2.662089        20450966.0
# 17  Australia  2005            2.626407        20176844.0
# 18  Australia  2004            2.594629        19932722.0
# 19  Australia  2003            2.567036        19720737.0
#
#     urban_population_pct  fertility_rate  age_dependency_ratio  \
# 0                 86.488           1.630             54.584773
# 1                 86.362           1.700             54.255816
# 2                 86.241           1.581             53.606125
# 3                 86.124           1.657             52.919758
# 4                 86.012           1.740             52.445515
# 5                 85.904           1.741             52.042421
# 6                 85.800           1.752             51.603446
# 7                 85.701           1.814             51.063301
# 8                 85.602           1.826             50.491061
# 9                 85.502           1.855             49.924367
# 10                85.402           1.920             49.328973
# 11                85.300           1.926             48.768238
# 12                85.182           1.928             48.363861
# 13                85.063           1.971             48.148257
# 14                84.943           1.984             48.125390
# 15                84.822           1.959             48.218323
# 16                84.700           1.908             48.329676
# 17                84.582           1.807             48.475300
# 18                84.463           1.768             48.649765
# 19                84.343           1.748             48.844562
#
#     life_expectancy  infant_mortality  health_exp_pc  ...  \
# 0         83.200000               3.2    6730.995117  ...
# 1         83.300000               3.2    7039.577637  ...
# 2         83.200000               3.2    5952.890625  ...
# 3         82.900000               3.2    5529.194824  ...
# 4         82.748780               3.2    5830.101562  ...
# 5         82.500000               3.2    5780.537109  ...
# 6         82.448780               3.2    5423.826660  ...
# 7         82.400000               3.3    5294.572266  ...
# 8         82.300000               3.4    6098.254395  ...
# 9         82.148780               3.5    5811.868652  ...
# 10        82.046341               3.6    6038.871582  ...
# 11        81.895122               3.8    5876.885254  ...
# 12        81.695122               4.0    4947.963379  ...
# 13        81.543902               4.2    3989.441162  ...
# 14        81.395122               4.4    4083.429443  ...
# 15        81.292683               4.5    3792.809814  ...
# 16        81.041463               4.7    3174.868652  ...
# 17        80.841463               4.8    2995.872559  ...
# 18        80.490244               4.8    2744.081055  ...
# 19        80.239024               4.9    2227.127686  ...
#
#     primary_school_enroll  secondary_school_enroll  tertiary_school_enroll  \
# 0               99.132988               133.277267              106.240761
# 1               99.929153               135.526566              112.688293
# 2               99.901108               137.490738              110.139221
# 3              100.199699               144.056564              109.759560
# 4              100.398712               136.105545              103.322090
# 5              100.637657               153.576126              109.993309
# 6              101.180687               155.594391              119.682777
# 7              101.665489               159.110764              119.679390
# 8              105.461601                      NaN                     NaN
# 9              105.802582                      NaN                     NaN
# 10             105.669724                      NaN                     NaN
# 11             105.274879                      NaN                     NaN
# 12             105.488503                      NaN                     NaN
# 13             105.215630                      NaN                     NaN
# 14             105.244629                      NaN                     NaN
# 15             105.422981                      NaN                     NaN
# 16             103.562561                      NaN                     NaN
# 17             103.397911                      NaN                     NaN
# 18             103.302063                      NaN                     NaN
# 19             102.854759                      NaN                     NaN
#
#     edu_exp_gdp_pct  gdp_per_capita  gross_capital_form_pct  inflation_rate  \
# 0           5.05916    64997.013654               23.768189        6.594097
# 1           5.34109    60607.778861               22.937240        2.863910
# 2           5.38625    51791.540180               22.427729        0.846906
# 3               NaN    54972.701789               23.391288        1.610768
# 4               NaN    57196.422078               24.646412        1.911401
# 5               NaN    53901.714539               24.176303        1.948647
# 6               NaN    49888.041084               25.448184        1.276991
# 7               NaN    56739.026535               26.273624        1.508367
# 8               NaN    62544.087377               26.727329        2.487923
# 9               NaN    68190.701004               27.873485        2.449889
# 10              NaN    68072.873234               27.716097        1.762780
# 11              NaN    62605.600458               26.464109        3.303850
# 12              NaN    52144.665471               26.784337        2.918340
# 13              NaN    42816.567400               27.364340        1.771117
# 14              NaN    49701.281784               28.603315        4.350299
# 15              NaN    41051.612065               27.501990        2.327611
# 16              NaN    36595.707155               27.504814        3.555288
# 17              NaN    34479.767930               27.456826        2.691832
# 18              NaN    30836.730682               27.063647        2.343255
# 19              NaN    23718.133850               25.936985        2.732596
#
#     unemployment_rate  trade_pct_gdp  fdi_inflows_pct
# 0               3.728      45.821770         4.161495
# 1               5.116      40.302480         2.024682
# 2               6.456      44.664456         1.353256
# 3               5.159      46.187502         2.781968
# 4               5.300      43.736065         4.250333
# 5               5.592      42.203732         3.636090
# 6               5.711      40.974079         3.560566
# 7               6.055      41.663932         3.470209
# 8               6.078      42.484023         4.304707
# 9               5.663      41.272879         3.453928
# 10              5.225      43.164296         3.720199
# 11              5.083      41.851132         4.688815
# 12              5.214      40.521589         3.094839
# 13              5.565      45.740863         3.115219
# 14              4.242      42.846776         4.277016
# 15              4.381      42.008020         5.197718
# 16              4.785      41.559447         4.082093
# 17              5.036      39.160747        -3.606928
# 18              5.399      37.009614         6.980717
# 19              5.933      40.201567         1.920995
#
# [20 rows x 22 columns]

# %% [markdown]
# ## Part 3:
# (2\%) Builds at least two visualizations (graphs/plots) from the data which help to understand or answer the questions of interest. These visualizations will be graded based on how much information they can effectively communicate to readers. Please make sure your visualization are sufficiently distinct from each other.

# %%
# importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import pandas as pd

# %%
# Please see screenshots attached in case Gradescope does not show the plot

# %% [markdown]
# Explain the graph you made above and the distribution of it. This one will be a side-by-side bar graph.

# %% [markdown]
# Here you want to create a heatmap of the numerical columns described in the dataset, what had the highest correlation coefficients and what attributes can we use for our analysis and ML practices for the future?

# %%
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_13.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ![LinePlot](plot_screenshots/lineplot.png)

# %% [markdown]
# Create a time-series plot of any type of attribute you want from the dataset, and describe how the distribution changed for specific countries overtime, what were some outliers and what stood out?

# %%
attr = "gdp_per_capita"
latest = int(gdp_clean_data["date"].max())

top20_countries = (
    gdp_clean_data[gdp_clean_data["date"] == latest]
    .nlargest(20, attr)["country"]
    .tolist()
)

subset = (
    gdp_clean_data[gdp_clean_data["country"].isin(top20_countries)]
    .dropna(subset=[attr])
    .sort_values(["country", "date"])
)

colors = plt.cm.tab20(np.linspace(0, 1, len(top20_countries)))

plt.figure(figsize=(12,7))

for (c, d), color in zip(subset.groupby("country"), colors):
    plt.plot(d["date"], d[attr], label=c, color=color, alpha=0.9, linewidth=1.8)

plt.title(f"{attr.replace('_',' ').title()} over Time (Top 20)", fontsize=14)
plt.xlabel("Year")
plt.ylabel(attr.replace('_',' ').title())
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", ncol=1, fontsize=9)
plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# The graph illustrates the change in GDP per capita for the world’s top 20 economies from 1980 to 2022, highlighting clear differences in economic growth patterns among developed and emerging nations. Overall, most countries show an upward trend, reflecting steady global economic expansion. Switzerland and the United States maintain the highest GDP per capita levels throughout the period, both exceeding $70,000 by 2022, while countries such as Germany, the United Kingdom, and Japan form a stable mid-range cluster. In contrast, emerging economies like China and India display rapid post-2000 growth, narrowing the gap with advanced nations. Noticeable dips around 2008 and 2020 correspond to the global financial crisis and the COVID-19 pandemic. The chart overall emphasizes long-term growth, resilience, and the gradual shift in global economic balance toward developing regions.
